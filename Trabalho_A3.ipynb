# %% [markdown]
# ## Processamento e Visualização de Dados

# %% [markdown]
# ### Aluno : Yago David Pimenta   RA : 800273

# %% [markdown]
# ### Trabalho A3 - Dados geográficos

# %% [markdown]
# #### Geopandas

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 60.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 50.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# #### Importando bibliotecas e o dataset

# %%
import matplotlib.pyplot as plt
import geopandas
import pandas as pd
# %matplotlib inline

# %% [markdown]
# #### Primeira Visualização : O dataset será sobre terremotos

# %% [markdown]
# Link : https://www.kaggle.com/datasets/usgs/earthquake-database

# %%
df = pd.read_csv("/content/database.csv")

# %% [markdown]
# Vamos ver a cara dele

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
df.shape
# Out:
# (23412, 21)

# %%
df['Type'].value_counts()
# Out:
# Earthquake           23232
# Nuclear Explosion      175
# Explosion                4
# Rock Burst               1
# Name: Type, dtype: int64

# %% [markdown]
# Percebemos que temos alguns tipos que não são de terremotos e não queremos eles

# %%
df = df[df['Type'] == 'Earthquake']

# %% [markdown]
# Também é possível ver que tem muitas colunas com Nan e que não são interessantes para análise , então irei tirar .

# %%
df = df[['Date', 'Time', 'Latitude', 'Longitude', 'Depth', 'Magnitude']]

# %%
gdf = geopandas.GeoDataFrame(df, geometry=geopandas.points_from_xy(df.Longitude, df.Latitude))
gdf.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Azimuthal Gap  \
# 0                     NaN        6.0             MW  ...            NaN
# 1                     NaN        5.8             MW  ...            NaN
# 2                     NaN        6.2             MW  ...            NaN
# 3                     NaN        5.8             MW  ...            NaN
# 4                     NaN        5.8             MW  ...            NaN
#
# ...

# %% [markdown]
# Estamos fazendo isso para poder plotar o mapa

# %%
world = geopandas\
.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# Com essa informação vamos plotar os terremotos agora

# %%
ax = world.plot(color='gray', edgecolor='yellow', figsize=(16,12))
gdf.plot(ax=ax, color='blue', markersize=3)
plt.show()

# %% [markdown]
# #### Segunda visualização : Barcelona

# %% [markdown]
# Link : https://raw.githubusercontent.com/jcanalesluna/bcn-geodata/master/districtes/districtes.geojson

# %%
url = 'https://raw.githubusercontent.com/jcanalesluna/bcn-geodata/master/districtes/districtes.geojson'
districts = geopandas.read_file(url)

# %%
districts
# Out:
#   ID_ANNEX ANNEXDESCR ID_TEMA               TEMA_DESCR ID_CONJUNT  CONJ_DESCR  \
# 0       01   Grup - I    0104  Unitats Administratives     010412  Districtes
# 1       01   Grup - I    0104  Unitats Administratives     010412  Districtes
# 2       01   Grup - I    0104  Unitats Administratives     010412  Districtes
# 3       01   Grup - I    0104  Unitats Administratives     010412  Districtes
# 4       01   Grup - I    0104  Unitats Administratives     010412  Districtes
# 5       01   Grup - I    0104  Unitats Administratives     010412  Districtes
# 6       01   Grup - I    0104  Unitats Administratives     010412  Districtes
# 7       01   Grup - I    0104  Unitats Administratives     010412  Districtes
# 8       01   Grup - I    0104  Unitats Administratives     010412  Districtes
# 9       01   Grup - I    0104  Unitats Administratives     010412  Districtes
#
#   ID_SUBCONJ SCONJ_DESC  ID_ELEMENT          ELEM_DESCR  ... ESTIL_ID  \
# ...

# %%
districts.to_file("districts.geojson", driver="GeoJSON")

# %%
ax= districts.plot(figsize=(10,6))
